# %% [markdown]
# <a href="https://colab.research.google.com/github/LaisST/Alura_Trilha_Analista_De_Dados/blob/main/Python%20para%20Dados%3A%20primeiros%20passos/CursoPython_Desafio_Pratica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercicios Mundo 1

# %% [markdown]
# ## Aula 1

# %% [markdown]
# Exercício Python 2: Faça um programa que leia o nome de uma pessoa e mostre uma mensagem de boas-vindas.

# %%
nome = input("Qual é o seu nome?")
print(f'Olá, {nome}! Seja bem vindo(a)!')
# Out:
# Qual é o seu nome?Lais
# Olá, Lais! Seja bem vindo(a)!

# %% [markdown]
# Exercício Python 3: Crie um programa que leia dois números e mostre a soma entre eles.

# %%
numero1 = int(input("Digite o primeiro número: "))
numero2 = int(input("Digite o segundo número: "))
soma = numero1 + numero2
print(f'A soma entre {numero1} e {numero2} é igual a {soma}')
# Out:
# Digite o primeiro número: 1
# Digite o segundo número: 2
# A soma entre 1 e 2 é igual a 3

# %% [markdown]
# Exercício Python 4: Faça um programa que leia algo pelo teclado e mostre na tela o seu tipo primitivo e todas as informações possíveis sobre ele.

# %%
texto = input("Digite algo:")
print(f'O tipo primitivo desse valor é {type(texto)}')
print(f'Só tem espaços? {texto.isspace()}')
print(f'É um número? {texto.isnumeric()}')
print(f'É alfabético? {texto.isalpha()}')
# Out:
# Digite algo:5
# O tipo primitivo desse valor é <class 'str'>
# Só tem espaços? False
# É um número? True
# É alfabético? False

# %% [markdown]
# Exercício Python 5: Faça um programa que leia um número Inteiro e mostre na tela o seu sucessor e seu antecessor.

# %%
numero = int(input("Digite um número:"))
sucessor = numero + 1
antecessor = numero - 1
print(f'Analisando o valor {numero}, identificamos que o antecessor é {antecessor} e o sucessor é {sucessor}.')
# Out:
# Digite um número:5
# Analisando o valor 5, identificamos que o antecessor é 4 e o sucessor é 6.

# %% [markdown]
# ## Aula 2

# %% [markdown]
# ### Estrutura Condicional

# %% [markdown]
# Vamos praticar o uso de estruturas condicionais como o if, else e elif a partir de algumas atividades. Agora que estamos avançando nos conteúdos, podemos tornar os desafios mais interessantes: vamos trabalhar com projetos de código! Solucione os problemas de aquecimento para se preparar para os projetos:

# %% [markdown]
# 1) Escreva um programa que peça à pessoa usuária para fornecer dois números e exibir o número maior.

# %%
num1 = int(input('Digite o primeiro número inteiro: '))
num2 = int(input('Digite o Segundo número inteiro: '))
if num1 > num2:
    print(f'O número maior é {num1}')
else:
    print(f'O número maior é {num2}')
# Out:
# Digite o primeiro número inteiro: 5
# Digite o Segundo número inteiro: 4
# O número maior é 5

# %% [markdown]
# 2) Escreva um programa que solicite o percentual de crescimento de produção de uma empresa e informe se houve um crescimento (porcentagem positiva) ou decrescimento (porcentagem negativa).

# %%
perc1 = float(input('Digite o percentual de crescimento da empresa: '))
if perc1 > 0:
    print('Houve um crescimento!')
else:
    print('Houve um decrescimento!')
# Out:
# Digite o percentual de crescimento da empresa: 30
# Houve um crescimento!

# %% [markdown]
# 3) Escreva um programa que determine se uma letra fornecida pela pessoa usuária é uma vogal ou consoante.

# %%
vogal = 'A,E,I,O,U'
letra = input('Digite uma letra:').upper()
if letra in vogal:
  print(f'A letra {letra} é uma vogal')
else:
  print(f'A letra {letra} não é uma vogal')
# Out:
# Digite uma letra:e
# A letra E é uma vogal

# %% [markdown]
# 4) Escreva um programa que leia valores médios de preços de um modelo de carro por 3 anos consecutivos e exiba o valor mais alto e mais baixo entre esses três anos.

# %%
valor1 = float(input('Digite o valor do primeiro ano: '))
valor2 = float(input('Digite o valor do segundo ano: '))
valor3 = float(input('Digite o valor do terceiro ano: '))

if valor1 > valor2:
    maior = valor1
else:
    maior = valor2

if valor3 > maior:
    maior = valor3


if valor1 < valor2:
    menor = valor1
else:
    menor = valor2

if valor3 < menor:
    menor = valor3

print(f'O maior valor é o {maior} e o menor valor é o {menor}')
# Out:
# Digite o valor do primeiro ano: 3000
# Digite o valor do segundo ano: 2500
# Digite o valor do terceiro ano: 3000
# O maior valor é o 3000.0 e o menor valor é o 2500.0

# %% [markdown]
# 5) Escreva um programa que pergunte sobre o preço de três produtos e indique qual é o produto mais barato para comprar.

# %%
pao_frances = float(input('Digite o preço do Pão Francês: R$ '))
pao_leite = float(input('Digite o preço do Pão de Leite: R$ '))
pao_queijo = float(input('Digite o preço do Pão de Queijo: '))
barato = 0
if pao_frances < pao_leite:
    barato = pao_frances
    tipo = 'Pão Francês'
elif pao_leite < barato:
    barato = pao_leite
    tipo = 'Pão de Leite'
else:
    barato = pao_queijo
    tipo = 'Pão de Queijo'

print(f'O produto mais barato é {tipo} que custa R$ {barato}')
# Out:
# Digite o preço do Pão Francês: R$ 2.5
# Digite o preço do Pão de Leite: R$ 1.5
# Digite o preço do Pão de Queijo: 1
# O produto mais barato é Pão de Queijo que custa R$ 1.0

# %% [markdown]
# ### Momento dos projetos

# %% [markdown]
# 10) Um programa deve ser escrito para ler dois números e, em seguida, perguntar à pessoa usuária qual operação ele deseja realizar. O resultado da operação deve incluir informações sobre o número - se é par ou ímpar, positivo ou negativo e inteiro ou decimal.

# %%
# Entrada
num1 = float(input('Digite o primeiro número: '))
num2 = float(input('Digite o segundo número: '))
operacao = input('Digite a operação que deseja realizar (+, -, *, /): ')

#Processamento
if operacao == '+':
    resultado = num1 + num2
    tipo = 'soma'
elif operacao == '-':
    resultado = num1 - num2
    tipo = 'subtração'
elif operacao == '*':
    resultado = num1 * num2
    tipo = 'multiplicação'
elif operacao == '/':
    resultado = num1 / num2
    tipo = 'divisão'
else:
    print('Operação inválida')
    exit()

if resultado % 2 == 0:
    par = 'par'
else:
    par = 'ímpar'

if resultado > 0:
    positivo = 'positivo'
else:
    positivo = 'negativo'

#Saída
print(f'O resultado da {tipo} é {resultado}.')
print(f'O resultado é {par} e {positivo}.')
# Out:
# Digite o primeiro número: 0
# Digite o segundo número: 0
# Digite a operação que deseja realizar (+, -, *, /): -
# O resultado da subtração é 0.0.
# O resultado é par e negativo.

# %% [markdown]
# 11) Escreva um programa que peça à pessoa usuária três números que representam os lados de um triângulo. O programa deve informar se os valores podem ser utilizados para formar um triângulo e, caso afirmativo, se ele é equilátero, isósceles ou escaleno. Tenha em mente algumas dicas:
#
# Três lados formam um triângulo quando a soma de quaisquer dois lados for maior que o terceiro;
#
# Triângulo Equilátero: três lados iguais;
#
# Triângulo Isósceles: quaisquer dois lados iguais;
#
# Triângulo Escaleno: três lados diferentes.

# %%
#Entrada
lado1 = float(input('Digite o primeiro lado do triângulo: '))
lado2 = float(input('Digite o segundo lado do triângulo: '))
lado3 = float(input('Digite o terceiro lado do triângulo: '))

#Processamento
if lado1 + lado2 > lado3 and lado1 + lado3 > lado2 and lado2 + lado3 > lado1:
    triangulo = "É Triangulo"
else:
    triangulo = "Não é Triangulo"

if lado1 == lado2 and lado1 == lado3:
    tipo = 'equilátero'
elif lado1 == lado2 or lado1 == lado3 or lado2 == lado3:
    tipo = 'isósceles'
else:
    tipo = 'escaleno'

print(f'Os lados {lado1}, {lado2} e {lado3} {triangulo}.')
print(f'O triângulo é {tipo}.')
# Out:
# Digite o primeiro lado do triângulo: 2
# Digite o segundo lado do triângulo: 3
# Digite o terceiro lado do triângulo: 2
# Os lados 2.0, 3.0 e 2.0 É Triangulo.
# O triângulo é isósceles.
